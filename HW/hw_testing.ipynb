# %%
import sympy

M = sympy.Matrix([
    [1, 0, 0, 0],
    [1, 1, 1, 2],
    [1, 2, 4, 2]
])

# Get the reduced row echelon form
M_rref, pivot_columns = M.rref()

# %%
print(M_rref)
# Out:
# Matrix([[1, 0, 0, 0], [0, 1, 0, 3], [0, 0, 1, -1]])
