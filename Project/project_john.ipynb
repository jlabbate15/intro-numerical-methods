# %% [markdown]
# NOTES CELL (TO BE DELETED PRIOR TO SUBMISSION)
#
# Things left to do:
# - Add one sentence to abstract depending on how much the code works.
# - John try one more time at code.
# - John look over intro.
# - Write discussion after look over code and then review quick.
# - Relative error plot.

# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as any collaborators you worked with:

# %%
COLLABORATORS = "Mohammed Haque and John Labbate"

# %% [markdown]
# ## To receive credit for this assignment, you must also fill out the [AI Use survey](https://forms.gle/ZhR5k8TdAeN8rj4CA)

# %% [markdown]
# ---

# %%
# %matplotlib inline
# %precision 16
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Final Project
#
# This notebook will provide a brief structure and rubric for presenting your final project.
#
# The purpose of the project is 2-fold
# * To give you an opportunity to work on a problem you are truly interested in (as this is the best way to actually learn something)
# * To demonstrate to me that you understand the overall workflow of problem solving from problem selection to implementation to discussion
#
# You can choose any subject area that interests you as long as there is a computational component to it.  However, please do not reuse projects or homeworks you have done in other classes.  This should be **your** original work.
#
# **You can work in teams, but clearly identify each persons contribution** and every team member should hand in their own copy of the notebook.
#
# ### Structure
# There are 5 parts for a total of 100 points that provide the overall structure of a mini research project.
#
# * Abstract
# * Introduction and Problem Description
# * Brief discussion of Computational approach and import of any additional packages
# * Implementation including tests
# * Discussion of results and future directions
#
# For grading purposes, please try to make this notebook entirely self contained.
#
# The project is worth about 2 problem sets and should be of comparable length (please: I will have about 100 of these to read and I am not expecting full 10 page papers).  The actual project does not necessarily have to work but in that case you should demonstrate that you understand why it did not work and what steps you would take next to fix it.
#
# Have fun

# %% [markdown]
# ## Abstract [10 pts]
#
# Provide a 1-2 paragraph abstract of the project in the style of a research paper.  The abstract should contain
#
# * A brief description of the problem
# * A brief justification describing why this problem is important/interesting to you
# * A general description of the computational approach
# * A brief summary of what you did and what you learned

# %% [markdown]
# Magnetic confinement fusion devices are the leading candidate for the realization of commercial fusion energy, however, they are still not physically well understood and have many engineering challenges to overcome to reach commercialization. In magnetic confinement fusion devices, a common metric to evaluate various physical aspects of a device or configuration is taking a bounce average of specific quantities such as the drift radially through the device for particles that are trapped in a magnetic well. These metrics can then be used for device improvements via optimization. The bouncing particles are called trapped particles as they are trapped in the magnetic well.
#
# In this project, we would like to recreate some of these quadrature methods to evaluate bounce averages in fusion devices for multiple magnetic-well bounce points of particles at different locations in a device. A bounce-averaged quantity has an integral of the form
# $$
# \langle g \rangle = 2 \int_{t_i}^{t_f} g\, dt,
# $$
# where the integral is evaluated between the initial $t_i$ and final $t_f$ points in the bounce orbit (over one half of the bounce, hence the factor of two, assuming the bounce is symmetric). In this Jupyter notebook we used methods from APMA4300 like cubic splines for the interpolation of the magnetic field in between known points and Gauss–Legendre quadrature methods to compute the bounce integrals. These techniques allow us to resolve the rapid spatial variation of the magnetic field along particle trajectories with high smoothness and numerical stability. By constructing accurate spline representations of the field, we ensure that the integrands used in the bounce calculations behave well under differentiation and integration. The use of Gauss–Legendre quadrature further improves the precision of the bounce-averaged quantities, enabling efficient evaluation even in regions where the particle motion becomes highly nonlinear.

# %% [markdown]
# ## Introduction [15 pts]
#
# In ~4-5 paragraphs, describe
# * The general problem you want to solve
# * Why it is important and what you hope to achieve.
#
# Please provide basic **references**, particularly if you are reproducing results from a paper. Also include any basic equations you plan to solve.
#
# Please use proper spelling and grammar.

# %% [markdown]
# A stellarator is a device that confines plasma using magnetic fields for extended periods, relying entirely on carefully shaped external magnetic coils. This design minimizes the need for large plasma currents, thereby reducing associated current-driven instabilities. The complex three-dimensional geometry of stellarator coils generates a fully three-dimensional magnetic field configuration that confines the plasma, making stellarators promising candidates for continuous, steady-state fusion energy production. The magnetic field can be designed to possess a hidden symmetry, which plays a key role in enhancing confinement. While more complex to design and construct, stellarators offer significant advantages in long-term plasma stability and operational efficiency.
#
# Significant advancements in stellarator research have been achieved in recent years, both computationally and in engineering. The Wendelstein 7-X (W7-X) [1] stellarator in Germany is the largest and most advanced device of its kind, demonstrating substantial improvements in plasma confinement and heating performance. These efforts, together with major advances in computational modeling and coil design optimization, have significantly expanded our understanding of stellarators and their potential to revolutionize fusion energy. The presence of symmetry in a stellarator’s magnetic field strength is known as *quasisymmetry*. Quasisymmetric stellarators are of particular importance because they offer excellent particle confinement. Optimizations targeting quasisymmetry—specifically quasi-axisymmetry (QA) and quasi-helical symmetry (QH)—have already led to stellarator configurations with exceptional confinement properties.[2]
#
# One way to better understand the confinement properties of a given equilibrium is to examine the magnetic field strength, $|B|$, along individual magnetic field lines. By tracing a field line and plotting $|B|$ as a function of the distance along the field line, we obtain a one-dimensional representation of the magnetic field structure experienced by a charged particle following that trajectory. Local minima in $|B|$ correspond to magnetic wells, which can trap particles via the magnetic mirror effect. Particles with sufficiently large perpendicular velocity relative to their parallel velocity will be reflected at regions of high $|B|$, executing bounce motion between two mirror points. The depth and spatial extent of these magnetic wells are therefore direct indicators of the plasma’s ability to confine particles and limit parallel losses along magnetic field lines.[3]
#
#
# Understanding the structure of $|B|$ along magnetic field lines and the resulting magnetic well geometry is therefore central to assessing and optimizing particle confinement in stellarator equilibria. Poorly shaped magnetic wells lead to enhanced parallel losses, large trapped-particle drifts, and increased neoclassical transport, all of which degrade plasma performance and confinement time. By contrast, equilibria that are designed to produce favorable $|B|$ profiles—such as quasisymmetric or omnigenous configurations—can significantly reduce bounce-averaged radial drifts and suppress neoclassical losses. Improving the structure of these magnetic wells directly translates to enhanced particle and energy confinement, reduced transport, and ultimately more efficient designs.

# %% [markdown]
# ### References

# %% [markdown]
# [1]V. V. Nemov, S. V. Kasilov, W. Kernbichler, M. F. Heyn; Evaluation of ν neoclassical transport in stellarators. Phys. Plasmas 1 December 1999; 6 (12): 4622–4632.
#
# [2]Dudt, D. & Kolemen, E. (2020). DESC: A Stellarator Equilibrium Solver.
#
# [3]Dinklage, A., Beidler, C. D., Helander, P. et al. “Magnetic configuration effects on the Wendelstein 7-X stellarator.” Nature Physics 14, 855–860 (2018)

# %% [markdown]
# ## Computational  Methods [10 pts]
#
# Describe the specific approach you will take to solve some concrete aspect of the general problem.
#
# You should  include all the numerical or computational methods you intend to use.  These can include methods or packages  we did not discuss in class but provide some reference to the method. You do not need to explain in detail how the methods work, but you should describe their basic functionality and justify your choices.

# %% [markdown]
# DESC is a computational code designed to solve fixed-boundary ideal magnetohydrodynamic (MHD) equilibria in stellarators using a pseudo-spectral numerical method. The code employs a global Fourier–Zernike polynomial basis to represent the magnetic flux surfaces, ensuring analyticity at the magnetic axis and providing efficient convergence properties.
#
# The flux surface coordinates $R(\rho, \theta, \zeta)$ and $Z(\rho, \theta, \zeta)$ are expanded in this basis as
#
# $$
# R(\rho, \theta, \zeta) = \sum_{n=-N}^{N} \sum_{m=-M}^{M} \sum_{l \in L} R_{lmn}\;\mathcal{Z}_{l}^{m}(\rho, \theta)\;\mathcal{F}^{n}(\zeta)
# $$
#
# $$
# Z(\rho, \theta, \zeta) = \sum_{n=-N}^{N} \sum_{m=-M}^{M} \sum_{l \in L} Z_{lmn}\;\mathcal{Z}_{l}^{m}(\rho, \theta)\;\mathcal{F}^{n}(\zeta)
# $$
#
# where $\rho$ is the normalized radial coordinate, $\theta$ is the poloidal angle, and $\zeta$ is the toroidal angle. These coordinates are defined for a toroidal geometry. Here, $\mathcal{F}^{n}(\zeta) = e^{in\zeta}$ represents the toroidal Fourier modes, and $\mathcal{Z}_{l}^{m}(\rho, \theta) = R_{l}^{m}(\rho) e^{im\theta}$ denotes the Zernike polynomials defined on the unit disk.
#
# The radial Zernike polynomials $R_{l}^{m}(\rho)$ are given by
#
# $$
# R_{l}^{m}(\rho) = \sum_{s=0}^{(l - |m|)/2} \frac{(-1)^s (l-s)!}{s! \left(\frac{l + |m|}{2} - s\right)! \left(\frac{l - |m|}{2} - s\right)!} \;\rho^{l-2s}
# $$
#
# where the index set
#
# $$
# L = \{ |m|,\, |m| + 2,\, |m| + 4,\, \ldots,\, L_{\text{max}} \}
# $$
#
# ensures that the radial dependence scales as $\rho^{|m|}$ near the magnetic axis, automatically satisfying the analyticity constraint and eliminating unphysical modes from the spectral representation.

# %% [markdown]
# We used cubic spline interpolation to ensure the interpolated magnetic fields were smooth and twice differentiable, which is important for accurately capturing curvature and avoiding sharp jumps in the first or second derivative. We want a well-behaved first and second derivative to ensure optimization is possible, as that is what these quantities are commonly used for. This method constructs piecewise cubic polynomials that join together with continuous first and second derivatives, producing a highly smooth approximation of the discretely sampled data. For numerical integration, we applied Gauss–Legendre quadrature, an efficient Gaussian quadrature technique that evaluates the integrand at optimally chosen points within each interval. Because these points and weights are selected to maximize accuracy, Gauss–Legendre quadrature provides very precise integral estimates even with a relatively small number of sampling points.

# %% [markdown]
# **If you need to install or import any additional python packages,  please provide complete installation instructions in the code block below**

# %%
# Provide complete installation or import information for external packages or modules here e.g.

# For the codes utilized for this project, all installations are done in the regime of a conda environment, which requires the installation of Anaconda or Miniconda.
# Utilize the instructions at https://www.anaconda.com/docs/getting-started/anaconda/install for installing Anaconda or Miniconda.

'''
##### Instructions to install the DESC code #####

# Run the following commands in a new terminal on MacOS or a Linux computing cluster:
git clone https://github.com/PlasmaControl/DESC.git
cd DESC
conda create --name APMA4300 'python>=3.10, <=3.13'
conda activate APMA4300
conda install pip
pip install --editable .
'''
import desc.io

'''
##### Instructions to install JAX #####

# Run the following commands in a new terminal
conda activate APMA4300
pip install jax==0.7.2
'''
import jax
import jax.numpy as jnp

# %% [markdown]
# ## Implementation [50 pts]
#
# Use the Markdown and Code blocks below to implement and document your methods including figures.  Only the first markdown block will be a grading cell but please add (not copy) cells in this section to organize your work.
#
# Please make the description of your problem readable by interlacing clear explanatory text with code (again with proper grammar and spelling).
# All code should be well described and commented.
#
# For at least one routine you code below, you should provide a test block (e.g. using `numpy.testing` routines, or a convergence plot) to validate your code.
#
# An **important** component of any computational paper is to demonstrate to yourself and others that your code is producing correct results.

# %% [markdown]
# We will begin with a DESC stellarator equilibrium file. This is a file that holds information of a magnetohydrodynamic (MHD) balanced stellarator configuration from which DESC has methods to calculate specific quantities [1]. A good starting point for this project is the magnetic field magnitude $B$ at each point on a specified grid within a stellarator, which can be calculated from this equilibrium file. We will use a common 3D coordinate system to describe a stellarator with closed flux surfaces $\psi,\alpha,\zeta$, which is a magnetic coordinate system where $\psi$ is the toroidal flux label, $\alpha$ is the label of a magnetic field line, and $\zeta$ is the toroidal angle [2]. In DESC, instead of $\psi$, $\rho$ is used. These two coordinates are connected:
#
# $$ \rho = \sqrt{\frac{\psi}{\psi_a}} $$
#
# where $\psi_a$ is the toroidal flux of the last closed flux surface. Note we are assuming closed toroidal flux surfaces exist in our stellarator equilibrium. The equilibrium file we will use is one of the provided example equilibria from DESC's tutorials. If the install above is followed exactly, the code below will access the same equilibrium with no extra work required except the specification of the path to the "DESC" repository top directory.
#
# We use this magnetic coordinates system because we assume energetic particles have low enough energies such that their orbits generally follow magnetic field lines. If the drifting motion (non-gyromotion) was large, these particles would not follow magnetic field lines.
#
# JAX is utilized for the implementation of this code in order to maintain compatibility with gradient methods in JAX. This is because these steps would likely be used in an optimization routine.

# %%
# Start with a DESC equilibrium file
eq = desc.io.load('qs_initial_guess.h5')

# %%
# Specify a psi, alpha, zeta grid to work with
num_alpha = 2
def make_grid(
        eq,
        rho = jnp.linspace(0.1,0.9,10),
        alpha = jnp.linspace(0,2*jnp.pi,num_alpha),
        zeta = jnp.linspace(0,2*jnp.pi,100)
        ):
    return eq._get_rtz_grid(
        radial = rho,
        poloidal = alpha,
        toroidal = zeta,
        coordinates = 'raz'
    )

# %%
# Calculate the magnetic field magnitude B on the specified grid above
def compute_from_eq(eq,grid):
    return eq.compute("|B|",grid=grid), eq.compute("B^zeta",grid=grid)

# %% [markdown]
# With the magnetic field known as discrete points in space, we can treat $B$ as a one-dimensional function for each $(\psi,\alpha)$ combination. We will want to perform an integration along a magnetic field line to get what is known as a "bounce integrated" quantity, which will be described in more detail shortly. We will integrate numerically using the grid points specified along each magnetic field line. Our results will be compared with the master branch bounce integration capabilities of DESC.
#
# Below, we create an interpolation for the bounce integration. For an optimization loop - where this code would commonly be used - many optimizers require the second derivative of relavent quantities to be well behaved. In this class, we learned a few interpolation methods. This project will thus apply cubic splines for all interpolations.

# %%
# Define a few helper functions that are jax differentiable
def polyfit_diff(x, y, deg): # jax.polyfit but differentiable 
    """
    Differentiable polynomial fit via least-squares.

    Args:
        x: shape (n,)
        y: shape (n,)
        deg: int, polynomial degree

    Returns:
        coeffs: shape (deg+1,), highest-power first
    """
    # Construct Vandermonde matrix (n, deg+1)
    A = jnp.vander(x, N=deg+1, increasing=False)

    # Solve least squares: minimize ||A c - y||^2
    coeffs, residuals, rank, s = jnp.linalg.lstsq(A, y, rcond=None)
    return coeffs

def affine_transform(x,a,b):
    """
    Map x from [a, b] to [-1, 1]

    Args:
        x: array
        a: lower bound of original interval
        b: upper bound of original interval
    """
    return 2 * (x - a) / (b - a) - 1

def arr_max_diff(arr):
    """
    Find the maximum of a 1D array (jax differentiable)

    Args:
        arr: 1D array

    Returns:
        dict with the index of max occurance and the value of the maximum
    """

    max_num = 99999999999999.9
    max_i = len(arr)+10 # this will throw an error if this function is not written correctly
    i_dumby = 0
    arr_dict = {'arr':arr,'i':i_dumby,'max_num':max_num,'max_i':max_i}
    def body_fun(i,arr_dict):
        cond_dict = {'arr':arr_dict['arr'],
                        'i':i,
                        'max_num':max_num,
                        'max_i':max_i}
        def tb_max(cond_dict):
            cond_dict['max_num'] = cond_dict['arr'][cond_dict['i']]
            cond_dict['max_i'] = cond_dict['i']
            return cond_dict
        def fb_max(cond_dict):
            return cond_dict
        return jax.lax.cond(cond_dict['arr'][i]<cond_dict['max_num'],tb_max,fb_max,cond_dict)
    out = jax.lax.fori_loop(0,len(arr),body_fun,arr_dict)
    return {'max_i':out['max_i'],'max_num':out['max_num']} # returns a dict with the index of max occurance and the value of the maximum

# %%
# Interpolation using cubic splines
def interpolate_old(f_eval,x,method='cubic splines'):
    """
    Interpolate a function known only by the function evaluated at specific grid points

    Args:
        f_eval: array of f evaluated at points in x interval
        x: zeta points at which f was evaluated at to form f_eval

    Returns:
        d_arr_full: array of polynomial's second derivatives at each point
    """
        
    if method == 'cubic splines':
        N = len(x) # degree of polynomial is the number of data points we have - 1
        A = jnp.zeros((N-2,N-2))
        b = jnp.zeros(N-2)
        for i in range(0,N-2):
            k = i+1
            A = A.at[i,i].set(2)
            if i+1<N-2:
                A = A.at[i,i+1].set(8)
            if i+2<N-2:
                A = A.at[i,i+2].set(2)
            b = b.at[i].set(6*(f_eval[k+1] - f_eval[k-1]))

        # Solve for the second derivative coefficients
        d_arr = jnp.linalg.solve(A,b)
        # use "natural splines", specify second derivative at each boundary to be zero
        d_arr_full = jnp.zeros(N)
        d_arr_full = d_arr_full.at[0].set(0) # Boundary derivative
        d_arr_full = d_arr_full.at[1:N-1].set(d_arr)  # Interior derivatives
        d_arr_full = d_arr_full.at[-1].set(0) # Boundary derivative

        def evaluate_interpolated(x_new):
            """
            Evaluate a function at a new point using cubic splines

            Args:
                x_new: array of new points to evaluate the function at
                x: x points at which f was evaluated at to form f_eval
                f_eval: array of f evaluated at points in x interval

            Returns:
                P: array of values of the function at x_new
            """
            
            results = jnp.zeros(len(x_new))
            for i in range(len(x_new)):

                # Find which interval contains x_new[i]
                k = arr_max_diff(-1*abs(x - x_new[i]))['max_i']
                
                # Get interval data
                # x_k = x[k]
                # x_kp1 = x[k + 1]
                y_k = f_eval[k] # y_k
                y_kp1 = f_eval[k + 1] # y_{k+1}
                d_k = d_arr_full[k] # d^*_k
                d_kp1 = d_arr_full[k + 1] # d^*_{k+1}

                s = affine_transform(x_new[i],0,1) # this is just one value
                
                # Evaluate cubic polynomial using the formula from lecture 06
                P = (1-s)**2 * (1 + 2*s) * y_k + s**2 * (3 - 2*s) * y_kp1 + s * (1-s)**2 * d_k - s**2 * (1-s) * d_kp1
                results = results.at[i].set(P)
            return results
        return evaluate_interpolated

    else:
        raise ValueError("Invalid interpolation method")

# %%
# CORRECTED interpolate function - JAX-compatible version

def interpolate(f_eval, x, method='cubic splines'):
    """
    Interpolate a function using cubic splines (JAX-compatible, corrected version)

    Args:
        f_eval: array of f evaluated at points in x interval
        x: x points at which f was evaluated at to form f_eval

    Returns:
        evaluate_interpolated: function that evaluates the interpolant at new points
    """
    if method == 'cubic splines':
        N = len(x)  # number of data points
        # Set up tridiagonal system for natural cubic splines
        # Solving for first derivatives d_k in transformed frame (uniform spacing)
        # System: 2*d_{k-1} + 8*d_k + 2*d_{k+1} = 6*(y_{k+1} - y_{k-1})
        A = jnp.zeros((N-2, N-2))
        b = jnp.zeros(N-2)
        for i in range(0, N-2):
            k = i+1  # interior point index
            A = A.at[i, i].set(2)
            if i+1 < N-2:
                A = A.at[i, i+1].set(8)
            if i+2 < N-2:
                A = A.at[i, i+2].set(2)
            b = b.at[i].set(6*(f_eval[k+1] - f_eval[k-1]))

        # Solve for the first derivatives d_k (in transformed frame)
        d_arr = jnp.linalg.solve(A, b)
        # Use "natural splines", specify first derivative at boundaries (set to 0 for natural)
        d_arr_full = jnp.zeros(N)
        d_arr_full = d_arr_full.at[0].set(0)  # Boundary derivative
        d_arr_full = d_arr_full.at[1:N-1].set(d_arr)  # Interior derivatives
        d_arr_full = d_arr_full.at[-1].set(0)  # Boundary derivative

        def evaluate_interpolated(x_new):
            """
            Evaluate a function at new points using cubic splines (JAX-compatible)

            Args:
                x_new: array of new points to evaluate the function at

            Returns:
                P: array of values of the function at x_new
            """
            # Compute cubic spline coefficients (first derivatives in transformed frame)
            d_star = d_arr_full
            
            # Clip x_new to be within [x[0], x[-1]] for extrapolation handling
            x_min = x[0]
            x_max = x[-1]
            x_new_clipped = jnp.clip(x_new, x_min, x_max)
            
            # Find which interval [x[k], x[k+1]] contains each x_new[i]
            # searchsorted returns index where x_new[i] would be inserted to maintain sorted order
            # Subtract 1 to get the left endpoint index k, then clip to [0, N-2]
            k_indices = jnp.clip(jnp.searchsorted(x, x_new_clipped, side='right') - 1, 0, N-2)
            
            # Get interval endpoints for each x_new point (vectorized)
            x_k = x[k_indices]  # shape: (len(x_new),)
            x_kp1 = x[k_indices + 1]  # shape: (len(x_new),)
            
            # Get function values at interval endpoints (vectorized)
            y_k = f_eval[k_indices]  # shape: (len(x_new),)
            y_kp1 = f_eval[k_indices + 1]  # shape: (len(x_new),)
            
            # Get first derivatives at interval endpoints (in transformed frame, vectorized)
            d_k = d_star[k_indices]  # shape: (len(x_new),)
            d_kp1 = d_star[k_indices + 1]  # shape: (len(x_new),)
            
            # Normalize x_new to s in [0,1] within each interval [x_k, x_kp1]
            h = x_kp1 - x_k  # interval lengths, shape: (len(x_new),)
            s = (x_new_clipped - x_k) / h  # s in [0,1], shape: (len(x_new),)
            
            # Evaluate cubic polynomial using formula from lecture 06 (vectorized)
            # P(s) = (1-s)^2(1+2s)*y_k + s^2(3-2s)*y_{k+1} + s(1-s)^2*d^*_k - s^2(1-s)*d^*_{k+1}
            P = (1-s)**2 * (1 + 2*s) * y_k + s**2 * (3 - 2*s) * y_kp1 + s * (1-s)**2 * d_k - s**2 * (1-s) * d_kp1
            
            return P
        return evaluate_interpolated

    else:
        raise ValueError("Invalid interpolation method")

# To use: Replace the existing interpolate function definition with this one

# %% [markdown]
# Since particles are assumed to be stuck to the magnetic field lines, the shape of the magnitude of the magnetic field curve along a field line will determine any mirroring or trapping that occurs for a particle. The magnitude of the magnetic field $B_c$ that causes a particle to turn around (an effect called mirroring [3]) is set by a parameter known as the pitch parameter $\lambda$.
# $$
# B_c = \frac{1}{\lambda}
# $$
# A routine is written in the following code cell to specify a grid of $B_c$ depending on the maximum and minimum values of the magnetic field magnitude for one flux surface ($\rho$), magnetic field line ($\alpha$), and magnetic well combination. This routine ensures that each particle is "trapped" in that it mirrors back and forth within a magnetic well (or "barely-trapped" if there is only one mirror point).

# %%
# Specify grid for B_c
from desc.equilibrium.coords import get_rtz_grid

def get_Bc_grid(eq,rho,num_Bc):
    """
    Get B_crit values for each rho considered

    Args:
        eq: DESC equilibrium
        rho: array of rho values
        num_Bc: integer number of B_crit values to consider

    Returns:
        2D array of B_crit values to consider, shape: (rho,Bc)
    """
    rho_bc = rho
    alpha_bc = jnp.array([0])
    zeta_bc = jnp.linspace(0, 12 * jnp.pi, 50)
    grid_bc = get_rtz_grid(eq, rho_bc, alpha_bc, zeta_bc, coordinates="raz")
    data = eq.compute(["min_tz |B|", "max_tz |B|"], grid=grid_bc) # min,max |B| on each rho
    return jnp.linspace(
        jnp.mean(data['min_tz |B|']),
        jnp.mean(data['max_tz |B|']),
        num_Bc
    )

# %% [markdown]
# The next cell determines the spatial point at which particle mirroring occurs is recorded for each combination of $\rho,\alpha,B_c,$ and magnetic well along the relevant field line. For simplicity, we will use the DESC method to do this. A method could be written using a root-finder, however, it will likely make this project too long.

# %%
# Identifying bounce/mirror points
from desc.integrals.bounce_integral import Bounce1D
from desc.integrals.quad_utils import (
    automorphism_sin,
    get_quadrature,
    grad_automorphism_sin,
)
from orthax.legendre import leggauss
from desc.grid import LinearGrid
from desc.grid import Grid

def get_bounce_points(eq,grid,Bcs,num_quad=32,num_well=3):
    """
    Find zeta bounce points for each rho,alpha,well,Bc considered

    Args:
        eq: DESC equilibrium
        grid: relevant grid
        Bcs: array of B_crits to consider
        num_quad: integer number of quadrature points to consider
        num_well: integer number of magnetic wells to consider

    Returns:
        array of zeta bounce point values to consider for each rho,alpha,well,Bc. shape (rho,alpha,well,Bc,zeta one and two)
    """

    # DESC method
    rho = jnp.unique(grid.nodes[:,0])
    _keys_1dr = ["iota", "iota_r", "min_tz |B|", "max_tz |B|"]
    _grid_1dr = LinearGrid(
            rho=rho, M=eq.M_grid, N=eq.N_grid, NFP=eq.NFP, sym=eq.sym
    )
    rho_vals = rho
    alpha_vals = jnp.linspace(0,2*jnp.pi,num_alpha)
    zeta_vals = jnp.linspace(0,10,15)
    bounce_grid = Grid.create_meshgrid(
        [rho_vals, alpha_vals, zeta_vals],
        coordinates="raz",
        NFP=eq.NFP
    )
    data = {
         'B^zeta': eq.compute("B^zeta",grid=bounce_grid)['B^zeta'],
         'B^zeta_z|r,a': eq.compute("B^zeta_z|r,a",grid=bounce_grid)['B^zeta_z|r,a'], 
         '|B|': eq.compute("|B|",grid=bounce_grid)['|B|'], 
         '|B|_z|r,a': eq.compute("|B|_z|r,a",grid=bounce_grid)['|B|_z|r,a']
    }
    quad = (
        get_quadrature(
            leggauss(num_quad),
            (automorphism_sin, grad_automorphism_sin),
        )
    )
    bounce = Bounce1D(bounce_grid, data, quad, is_reshaped=False)
    return bounce.points(Bcs, num_well=num_well)

# %% [markdown]
# Once each bounce point/mirror point has been identified, the actual integration over a period of mirroring may be calculated.
# $$
# \langle f \rangle_b = \frac{2}{v\tau_b}\int_{l_0}^{l_f}\frac{f}{\sqrt{1-\frac{B}{B_c}}}dl
# $$
# This integral is what results from a change of variables from bounce times to bounce length along a magnetic field line. The details of this derivation won't be shown in this report, but can be found in [4]. This integral will be calculated for each $\rho,\alpha,B_c,$ and magnetic well combination using the Gauss-Legendre quadrature method. The quadrature weights and associated quantities are defined in the following cell.

# %%
# Create quadratures
def get_quad_leggaus(rho,Bcs,points,num_quad=32):
    """
    Find quadrature points using the Gauss-Legendre quadrature

    Args:
        points: array of bounce points
        num_quad: number of quadrature points

    Returns:
        B, B_sup_zeta evaluated at quadrature points
    """
    z1 = points[0] # (rho, alpha, Bc, well)
    z2 = points[1] # (rho, alpha, Bc, well)
    x_ref, w_ref = leggauss(num_quad)
    x_ref = jnp.broadcast_to(x_ref[None,None,None,None,...],(z1.shape[0],z1.shape[1],z1.shape[2],z1.shape[3],num_quad))
    z1 = jnp.broadcast_to(z1[...,None],(z1.shape[0],z1.shape[1],z1.shape[2],z1.shape[3],num_quad))
    z2 = jnp.broadcast_to(z2[...,None],(z2.shape[0],z2.shape[1],z2.shape[2],z2.shape[3],num_quad))
    zeta = 0.5*(z1 + z2) + 0.5*(z2 - z1) * x_ref # shape (rho, alpha, Bc, well, num_quad)
    dzetadx  = 0.5 * (z2 - z1) # shape (rho, alpha, Bc, well, num_quad)
    
    w_ref = jnp.broadcast_to(w_ref[None,None,None,None,...],(z1.shape[0],z1.shape[1],z1.shape[2],z1.shape[3],num_quad))
    return zeta, w_ref, dzetadx  # integrate: sum(w_ref * f(zeta) * x_to_zeta_jac)

# %% [markdown]
# To now develop the integral numerically, we must keep all our variable changes in order. We can write this integral shown above with $g = \frac{f}{\sqrt{1-\frac{B}{B_c}}}$ in a way that allows the use of the quantities we have considered in this document so far:
#
# $$
# \int_{l_0}^{l_f}g(l)dl = \int_{\zeta_1}^{\zeta_2}g(\zeta)\frac{dl}{d\zeta}d\zeta = \int_{x_1}^{x_2}g(x)\frac{dl}{d\zeta}\frac{d\zeta}{dx}dx
# $$
#
# where $x=[-1,1]$ defines the grid of quadratures.

# %% [markdown]
# $g$ is some callable function that will be defined later in this code.
#
# $\frac{d\zeta}{dx}$ is the Jacobian from $\zeta$ to $x$ which has been defined in the get_quad_leggaus() method above.
#
# $\frac{dl}{d\zeta}$ is known from [2] to be:
#
# $$
# \frac{dl}{d\zeta} = \left| \frac{\mathbf{B}}{\mathbf{B} \cdot \mathbf{\nabla} \zeta} \right| = \frac{|\mathbf{B}|}{|\mathbf{B^\zeta}|} = \frac{1}{|\mathbf{b^\zeta}|}
# $$
#
# These parameters may be calculated at the quadrature points using the following code.

# %%
from jax import vmap
def compute_Bs_quad(eq,grid,zeta_quad):
    """
    Find B and B_sup_zeta at quadrature zeta points

    Args:
        eq: DESC equilibrium
        grid: relevant grid
        zeta_quad: zeta quadrature points

    Returns:
        B, B_sup_zeta evaluated at quadrature points
    """
    rhos_shape = len(jnp.unique(grid.nodes[:,0]))
    alpha_shape = num_alpha
    zeta_shape = len(jnp.unique(grid.nodes[:,2]))

    # Extract unique zeta coordinates
    zeta_knots = jnp.unique(grid.nodes[:, 2])  # zeta coordinates, 1D array
    
    # Get B and B_sup_zeta data from equilibrium
    B_data, B_sup_zeta_data = compute_from_eq(eq=eq, grid=grid)
    
    # Extract arrays from dictionaries and reshape to (num_rho, num_alpha, num_zeta)
    # B_3d = B_data['|B|'].reshape((zeta_shape, rhos_shape, alpha_shape)).transpose(1,2,0)
    # B_sup_zeta_3d = B_sup_zeta_data['B^zeta'].reshape((zeta_shape, rhos_shape, alpha_shape)).transpose(1,2,0)

    # DESC returns data in Fortran (column-major) order for meshgrids
    # For coordinates "raz", rho varies fastest, then alpha, then zeta
    # So reshape directly to (num_rho, num_alpha, num_zeta) with Fortran order
    B_3d = B_data['|B|'].reshape((rhos_shape, alpha_shape, zeta_shape), order='F')
    B_sup_zeta_3d = B_sup_zeta_data['B^zeta'].reshape((rhos_shape, alpha_shape, zeta_shape), order='F')


    # Define function to interpolate for a single (rho, alpha) field line
    def interpolate_single_fieldline(B_1d, zeta_quad_1d):
        """Interpolate B along a single field line at given quadrature points"""
        B_spline = interpolate(B_1d, zeta_knots, method='cubic splines')
        return B_spline(x_new=zeta_quad_1d)
    
    # Define function to handle (Bc, well) dimensions for one (rho, alpha)
    def interpolate_for_bc_well(B_1d, zeta_quad_bc_well):
        """
        Interpolate for one (rho, alpha) at all (Bc, well) quadrature points
        
        Args:
            B_1d: B values for one (rho, alpha), shape (num_zeta,)
            zeta_quad_bc_well: quadrature points, shape (num_Bc, num_well, num_quad)
        
        Returns:
            B interpolated, shape (num_Bc, num_well, num_quad)
        """
        # vmap over (Bc, well) dimensions
        return vmap(
            vmap(interpolate_single_fieldline, in_axes=(None, 0)), 
            in_axes=(None, 0))(B_1d, zeta_quad_bc_well)
    
    # vmap over (rho, alpha) axes
    # B_3d: (num_rho, num_alpha, num_zeta), zeta_quad: (num_rho, num_alpha, num_Bc, num_well, num_quad)
    interpolate_over_ra = vmap(
        vmap(interpolate_for_bc_well, in_axes=(0, 0)), 
        in_axes=(0, 0))
    
    # Apply interpolation
    B_quad = interpolate_over_ra(B_3d, zeta_quad)  # Shape: (num_rho, num_alpha, num_Bc, num_well, num_quad)
    B_sup_zeta_quad = interpolate_over_ra(B_sup_zeta_3d, zeta_quad)  # zeta_quad shape: (rho,alpha,Bc,well,num_quad), Output shape: (num_rho, num_alpha, num_Bc, num_well, num_quad)
    
    return B_quad, B_sup_zeta_quad

# %%
# Integrate!
def bounce_integrate(eq,grid,f,num_well,num_Bc,num_quad):
    """
    Integrate f over a bounce period

    Args:
        eq: DESC equilibrium
        grid: relevant user-specifiedgrid
        f: callable function to be integrated
        num_well: integer number of magnetic wells to consider
        num_Bc: integer number of Bc to consider
        num_quad: integer number of quadrature points to consider

    Returns:
        array of bounce integrated values of f size (rho,alpha,Bc,well)
    """

    rho = jnp.unique(grid.nodes[:, 0])
    Bcs = get_Bc_grid(eq,rho,num_Bc=num_Bc) # determine critical magnetic field values
    bounce_points = get_bounce_points(eq,grid,Bcs,num_well=num_well) # determine bounce points based on B_crits
    print(bounce_points[0][:,0,0,0]) # debugging
    zeta_quad, w_ref, dzetadx = get_quad_leggaus(rho,Bcs,bounce_points,num_quad=num_quad) # determine zeta quadrature points, output shapes are (rho,alpha,Bc,well,num_quad)
    B_quad, B_sup_zeta_quad = compute_Bs_quad(eq,grid,zeta_quad) # determine B and B_sup_zeta at quadrature points
    dldzeta = B_quad/jnp.abs(B_sup_zeta_quad)
    data_null = {'null':0} # dummy, not used, but needed input for pure DESC case
    Bcs = jnp.broadcast_to(Bcs[None,None,:,None,None],(B_quad.shape[0],B_quad.shape[1],B_quad.shape[2],B_quad.shape[3],B_quad.shape[4]))

    return jnp.sum(f(data_null,B_quad,pitch=safediv(1,Bcs)) * dldzeta * dzetadx * w_ref,axis=-1) # should have an output shape (rho,alpha,Bc,well)

# %% [markdown]
# $$\textbf{TESTING}$$

# %% [markdown]
# This code will provide an example integration quantity to consider. This quantity will be used to test this code.

# %%
# Example function to be considered for bounce integration
from desc.utils import safediv
f_test = lambda data, B, pitch: safediv(2.0, jnp.sqrt(jnp.abs(1 - pitch * B))) # test function, this is particle velocity * time
# f_test = lambda data, B, pitch: 1 # test function
grid = make_grid(eq=eq) # grid to use for both methods

# %%
# Useful definitions
num_quad = 32 # number of quadrature points to use. Always using 32 for this project
num_Bc = 5 # number of critical magnetic field values to use. Always using 10 for this project
num_well = 3 # number of magnetic wells to consider. Always use 3 for this project

# %%
# Using purely DESC methods to test bounce integration (not yet running)
from desc.grid import Grid
def DESC_test(eq,f_test,num_Bc,num_quad,num_alpha,grid):

    rho_vals = jnp.unique(grid.nodes[:,0])
    alpha_vals = jnp.linspace(0,2*jnp.pi,num_alpha)
    zeta_vals = jnp.linspace(0,10,15)
    bounce_grid = Grid.create_meshgrid(
        [rho_vals, alpha_vals, zeta_vals],
        coordinates="raz",
        NFP=eq.NFP
    )
    data = {
         'B^zeta': eq.compute("B^zeta",grid=bounce_grid)['B^zeta'],
         'B^zeta_z|r,a': eq.compute("B^zeta_z|r,a",grid=bounce_grid)['B^zeta_z|r,a'], 
         '|B|': eq.compute("|B|",grid=bounce_grid)['|B|'], 
         '|B|_z|r,a': eq.compute("|B|_z|r,a",grid=bounce_grid)['|B|_z|r,a']
    }
    quad = (
        get_quadrature(
            leggauss(num_quad),
            (automorphism_sin, grad_automorphism_sin),
        )
    )

    Bcs_DESC = get_Bc_grid(eq,rho=rho_vals,num_Bc=num_Bc) # this needs to be a 2d array, not 1d

    bounce = Bounce1D(bounce_grid, data, quad, is_reshaped=False)
    points = bounce.points(Bcs_DESC, num_well=num_well)
    print(points[0][:,0,0,0]) # debugging
    return bounce.integrate(
        integrand=[f_test],
        pitch_inv=Bcs_DESC,
        points=points
    )

# %%
# Numpy tests: Matching the DESC default answer to our methods

grid = grid.source_grid # use source grid to avoid remapping to rho,theta,zeta coordinates (DESC bug)

# Using purely DESC methods to test bounce integration (now running)
f_bounceint_DESC = DESC_test(eq,f_test,num_Bc,num_quad,num_alpha,grid) # shape (rho,alpha,Bc,well)

# Using this project's methods to test bounce integration
f_bounceint_test = bounce_integrate(eq,grid,f_test,num_Bc=num_Bc,num_well=num_well,num_quad=num_quad) # nothing like a good ol' one liner!

# Numpy testing
print("Numpy testing on pre-determined grid")
numpy.testing.assert_allclose(actual=f_bounceint_test,desired=f_bounceint_DESC,rtol=1e-1)
print("Success!")
# Out:
# [0.                0.                0.                0.
#  0.                0.                4.302222801507292 4.265964487742617
#  4.227373615865457 4.19044559125694 ]
# [0.                0.                0.                0.
#  0.                0.                4.302222801507292 4.265964487742617
#  4.227373615865457 4.19044559125694 ]
# Numpy testing on pre-determined grid
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[89], line 14
#      12 # Numpy testing
#      13 print("Numpy testing on pre-determined grid")
# ---> 14 numpy.testing.assert_allclose(actual=f_bounceint_test,desired=f_bounceint_DESC,rtol=1e-1)
#      15 print("Success!")
#
#     [... skipping hidden 1 frame]
#
# ...

# %% [markdown]
# Although this code is not passing the numpy tests, it may be useful to visualize the relative errors between the default DESC calculations and our calculcations. Note where relative error = 0 are where a particle in the relevant $(\rho,\alpha,B_c,well)$ was found to not be trapped in a magnetic well.

# %%
# A plot of relative error to test and show mismatched results
rel_err = safediv(jnp.abs(f_bounceint_test - f_bounceint_DESC),jnp.abs(f_bounceint_DESC))
fig,ax = plt.subplots()
ax.plot(jnp.unique(grid.nodes[:,0]),rel_err[:,0,5,0])
ax.set_title(r"Relative Error of Bounce Integration Over a $\rho$ Grid")
ax.set_xlabel(r"$\rho$")
ax.set_ylabel("Relative Error")
plt.show()

# %% [markdown]
# While the numbers outputted from this code are inconsistent with the DESC master branch code, the methods written are at least shown to be differentiable (usable for optimization with up to second-order derivative methods) in the cell below.

# %%
# Extra test: Differentiable for optimization?
test = jax.grad(bounce_integrate)
print('Success!')
# Out:
# Success!

# %% [markdown]
# References for Implementation
#
# [1] Simulation and Optimization for Stellarators (DESC). (n.d.). List of variables — DESC documentation. Read the Docs. Retrieved December 11, 2025, from https://desc-docs.readthedocs.io/en/stable/variables.html.
#
# [2] Imbert-Gérard, L.-M., Paul, E. J., & Wright, A. M. (2024). An introduction to stellarators: From magnetic fields to symmetries and optimization. SIAM.
#
# [3] Goldston, R. J., & Rutherford, P. H. (1995). Introduction to plasma physics. Taylor & Francis.
#
# [4] Velasco, J. L., Calvo, I., Mulas, S., Sánchez, E., Parra, F. I., & Cappa, A. (2021). A model for the fast evaluation of prompt losses of energetic ions in stellarators. Nuclear Fusion, 61(11), 116059.

# %% [markdown]
# ## Discussion [15 pts]
#
# Evaluate the results of your project including
# * Why should I believe that your numerical results are correct (convergence, test cases etc)?
# * Did the project work (in your opinion)?
# * If yes:  what would be the next steps to try
# * If no:  Explain why your approach did not work and what you might do to fix it.
